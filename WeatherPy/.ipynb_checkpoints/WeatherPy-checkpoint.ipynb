# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
print(cities[:5])
# Out:
# 612
# ['hue', 'dekoa', 'lourdes', 'cabo san lucas', 'anadyr']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base = "https://api.openweathermap.org/data/2.5/weather?q="
api = "&appid=" + weather_api_key + "&units=imperial"


lat = []
lng = []
cloud = []
country = []
date = []
humidity = []
max_temp = []
wind_speed = []
name = []

# url = base + cities[0] + api
# print(url)
# response = requests.get(url).json()
# print(json.dumps(response, indent=4, sort_keys=True))
# wind.append(response['wind']['speed'])

print('Beginning Data Retrieval')     
print('-----------------------------')


for city in range(len(cities)):
    try:
        print(f"Processing Record {city + 1} of Set | {cities[city]}")
    
        # Get city weather data
        url = base + cities[city] + api
        # print(url)
        response = requests.get(url).json()
        #print(json.dumps(response, indent=4, sort_keys=True))
    
        # Save weather data
        wind_speed.append(response['wind']['speed'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        max_temp.append(response['main']['temp_max'])
        name.append(cities[city])
        
    except:
        print('City not found. Skipping...')    

print('-----------------------------')
print('Data Retrieval Complete')      
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set | hue
# Processing Record 2 of Set | dekoa
# City not found. Skipping...
# Processing Record 3 of Set | lourdes
# Processing Record 4 of Set | cabo san lucas
# Processing Record 5 of Set | anadyr
# Processing Record 6 of Set | puerto ayora
# Processing Record 7 of Set | east london
# Processing Record 8 of Set | imola
# Processing Record 9 of Set | mecca
# Processing Record 10 of Set | mataura
# Processing Record 11 of Set | kavieng
# Processing Record 12 of Set | watsa
# Processing Record 13 of Set | punta arenas
# Processing Record 14 of Set | saint-pierre
# Processing Record 15 of Set | rikitea
# Processing Record 16 of Set | saint george
# Processing Record 17 of Set | tasiilaq
# Processing Record 18 of Set | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set | cockburn town
# Processing Record 20 of Set | saint-philippe
# Processing Record 21 of Set | ketchikan
# Processing Record 22 of Set | rio gallegos
# Processing Record 23 of Set | hilo
# Processing Record 24 of Set | akyab
# Processing Record 25 of Set | tuktoyaktuk
# Processing Record 26 of Set | hermanus
# Processing Record 27 of Set | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set | jamestown
# Processing Record 29 of Set | ushuaia
# Processing Record 30 of Set | ponta do sol
# Processing Record 31 of Set | vaini
# Processing Record 32 of Set | coihaique
# Processing Record 33 of Set | faanui
# Processing Record 34 of Set | hobart
# Processing Record 35 of Set | bredasdorp
# Processing Record 36 of Set | hithadhoo
# Processing Record 37 of Set | utica
# Processing Record 38 of Set | yellowknife
# Processing Record 39 of Set | atuona
# Processing Record 40 of Set | manutuke
# Processing Record 41 of Set | nanortalik
# Processing Record 42 of Set | port macquarie
# Processing Record 43 of Set | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set | puerto del rosario
# Processing Record 45 of Set | havoysund
# Processing Record 46 of Set | narsaq
# Processing Record 47 of Set | cape town
# Processing Record 48 of Set | qui nhon
# Processing Record 49 of Set | amderma
# City not found. Skipping...
# Processing Record 50 of Set | carnarvon
# Processing Record 51 of Set | kirakira
# Processing Record 52 of Set | kahului
# Processing Record 53 of Set | vila franca do campo
# Processing Record 54 of Set | touros
# Processing Record 55 of Set | isparta
# Processing Record 56 of Set | nome
# Processing Record 57 of Set | butaritari
# Processing Record 58 of Set | tagusao
# Processing Record 59 of Set | samarai
# Processing Record 60 of Set | georgetown
# Processing Record 61 of Set | port elizabeth
# Processing Record 62 of Set | perry
# Processing Record 63 of Set | mys shmidta
# City not found. Skipping...
# Processing Record 64 of Set | koboko
# Processing Record 65 of Set | ngukurr
# City not found. Skipping...
# Processing Record 66 of Set | barrow
# Processing Record 67 of Set | paamiut
# Processing Record 68 of Set | abha
# Processing Record 69 of Set | pangnirtung
# Processing Record 70 of Set | naze
# Processing Record 71 of Set | albany
# Processing Record 72 of Set | fukue
# Processing Record 73 of Set | cabo rojo
# Processing Record 74 of Set | union
# Processing Record 75 of Set | avarua
# Processing Record 76 of Set | belushya guba
# City not found. Skipping...
# Processing Record 77 of Set | nguiu
# City not found. Skipping...
# Processing Record 78 of Set | dikson
# Processing Record 79 of Set | yanan
# City not found. Skipping...
# Processing Record 80 of Set | hambantota
# Processing Record 81 of Set | arraial do cabo
# Processing Record 82 of Set | maldonado
# Processing Record 83 of Set | tiksi
# Processing Record 84 of Set | saint paul
# Processing Record 85 of Set | ancud
# Processing Record 86 of Set | holmestrand
# Processing Record 87 of Set | eina
# Processing Record 88 of Set | qaanaaq
# Processing Record 89 of Set | college
# Processing Record 90 of Set | wuda
# Processing Record 91 of Set | yuli
# Processing Record 92 of Set | vaitupu
# City not found. Skipping...
# Processing Record 93 of Set | pemba
# Processing Record 94 of Set | bababe
# City not found. Skipping...
# Processing Record 95 of Set | palmer
# Processing Record 96 of Set | busselton
# Processing Record 97 of Set | rundu
# Processing Record 98 of Set | smirnykh
# Processing Record 99 of Set | klaksvik
# Processing Record 100 of Set | port hedland
# Processing Record 101 of Set | new norfolk
# Processing Record 102 of Set | kapaa
# Processing Record 103 of Set | sabha
# Processing Record 104 of Set | khatanga
# Processing Record 105 of Set | gracanica
# Processing Record 106 of Set | mineiros
# Processing Record 107 of Set | saskylakh
# Processing Record 108 of Set | anzio
# Processing Record 109 of Set | bonthe
# Processing Record 110 of Set | torbay
# Processing Record 111 of Set | margate
# Processing Record 112 of Set | sao filipe
# Processing Record 113 of Set | dano
# Processing Record 114 of Set | oudtshoorn
# Processing Record 115 of Set | tokur
# Processing Record 116 of Set | tsihombe
# City not found. Skipping...
# Processing Record 117 of Set | saldanha
# Processing Record 118 of Set | wakkanai
# Processing Record 119 of Set | mount isa
# Processing Record 120 of Set | aykhal
# Processing Record 121 of Set | port alfred
# Processing Record 122 of Set | namibe
# Processing Record 123 of Set | hermitage
# Processing Record 124 of Set | samusu
# City not found. Skipping...
# Processing Record 125 of Set | vaitape
# Processing Record 126 of Set | grand river south east
# City not found. Skipping...
# Processing Record 127 of Set | saint-francois
# Processing Record 128 of Set | san carlos de bariloche
# Processing Record 129 of Set | angoram
# Processing Record 130 of Set | daru
# Processing Record 131 of Set | pacifica
# Processing Record 132 of Set | santa cruz del sur
# Processing Record 133 of Set | aksarka
# Processing Record 134 of Set | bluff
# Processing Record 135 of Set | sobolevo
# Processing Record 136 of Set | oranjemund
# Processing Record 137 of Set | wahran
# City not found. Skipping...
# Processing Record 138 of Set | alofi
# Processing Record 139 of Set | san roque
# Processing Record 140 of Set | nizhneyansk
# City not found. Skipping...
# Processing Record 141 of Set | kaitangata
# Processing Record 142 of Set | mar del plata
# Processing Record 143 of Set | mahebourg
# Processing Record 144 of Set | balikpapan
# Processing Record 145 of Set | longyearbyen
# Processing Record 146 of Set | mayo
# Processing Record 147 of Set | kruisfontein
# Processing Record 148 of Set | boatlaname
# City not found. Skipping...
# Processing Record 149 of Set | kearney
# Processing Record 150 of Set | misratah
# Processing Record 151 of Set | guerrero negro
# Processing Record 152 of Set | oistins
# Processing Record 153 of Set | thompson
# Processing Record 154 of Set | pergamino
# Processing Record 155 of Set | vao
# Processing Record 156 of Set | boa vista
# Processing Record 157 of Set | nabire
# Processing Record 158 of Set | sao joao da barra
# Processing Record 159 of Set | tuatapere
# Processing Record 160 of Set | willowmore
# Processing Record 161 of Set | vardo
# Processing Record 162 of Set | hasaki
# Processing Record 163 of Set | kilindoni
# Processing Record 164 of Set | iqaluit
# Processing Record 165 of Set | batticaloa
# Processing Record 166 of Set | koulikoro
# Processing Record 167 of Set | bose
# Processing Record 168 of Set | grand-lahou
# Processing Record 169 of Set | hami
# Processing Record 170 of Set | muros
# Processing Record 171 of Set | ponta pora
# Processing Record 172 of Set | malanje
# Processing Record 173 of Set | iralaya
# Processing Record 174 of Set | nuuk
# Processing Record 175 of Set | constantine
# Processing Record 176 of Set | hailey
# Processing Record 177 of Set | broome
# Processing Record 178 of Set | norman wells
# Processing Record 179 of Set | hay river
# Processing Record 180 of Set | imaculada
# Processing Record 181 of Set | hanzhong
# Processing Record 182 of Set | ilulissat
# Processing Record 183 of Set | harlingen
# Processing Record 184 of Set | kampot
# Processing Record 185 of Set | high level
# Processing Record 186 of Set | litovel
# Processing Record 187 of Set | znamenka
# Processing Record 188 of Set | nikolskoye
# Processing Record 189 of Set | pochutla
# Processing Record 190 of Set | nampula
# Processing Record 191 of Set | puerto lempira
# Processing Record 192 of Set | auki
# Processing Record 193 of Set | marzuq
# Processing Record 194 of Set | esperance
# Processing Record 195 of Set | sentyabrskiy
# City not found. Skipping...
# Processing Record 196 of Set | evensk
# Processing Record 197 of Set | port blair
# Processing Record 198 of Set | vestbygda
# City not found. Skipping...
# Processing Record 199 of Set | pevek
# Processing Record 200 of Set | yar-sale
# Processing Record 201 of Set | valdivia
# Processing Record 202 of Set | ust-nera
# Processing Record 203 of Set | erenhot
# Processing Record 204 of Set | bethel
# Processing Record 205 of Set | kuche
# City not found. Skipping...
# Processing Record 206 of Set | granger
# Processing Record 207 of Set | bilma
# Processing Record 208 of Set | illoqqortoormiut
# City not found. Skipping...
# Processing Record 209 of Set | nyzy
# Processing Record 210 of Set | kodiak
# Processing Record 211 of Set | cherskiy
# Processing Record 212 of Set | chumikan
# Processing Record 213 of Set | bathsheba
# Processing Record 214 of Set | souillac
# Processing Record 215 of Set | agadir
# Processing Record 216 of Set | vogar
# Processing Record 217 of Set | sibolga
# Processing Record 218 of Set | hervey bay
# Processing Record 219 of Set | lompoc
# Processing Record 220 of Set | mrirt
# City not found. Skipping...
# Processing Record 221 of Set | guadalupe y calvo
# Processing Record 222 of Set | batemans bay
# Processing Record 223 of Set | atikokan
# Processing Record 224 of Set | zhigansk
# Processing Record 225 of Set | zhuanghe
# Processing Record 226 of Set | ostrovnoy
# Processing Record 227 of Set | yenagoa
# Processing Record 228 of Set | sokoto
# Processing Record 229 of Set | tustin foothills
# City not found. Skipping...
# Processing Record 230 of Set | lebu
# Processing Record 231 of Set | salinopolis
# Processing Record 232 of Set | asau
# Processing Record 233 of Set | zyryanka
# Processing Record 234 of Set | illela
# Processing Record 235 of Set | zaysan
# Processing Record 236 of Set | cacequi
# Processing Record 237 of Set | sinnamary
# Processing Record 238 of Set | bengkulu
# Processing Record 239 of Set | grand gaube
# Processing Record 240 of Set | afyonkarahisar
# Processing Record 241 of Set | sayyan
# Processing Record 242 of Set | kurchum
# Processing Record 243 of Set | alyangula
# Processing Record 244 of Set | imeni poliny osipenko
# Processing Record 245 of Set | conde
# Processing Record 246 of Set | taunggyi
# Processing Record 247 of Set | ranfurly
# Processing Record 248 of Set | beyneu
# Processing Record 249 of Set | bonavista
# Processing Record 250 of Set | pringsewu
# Processing Record 251 of Set | castro
# Processing Record 252 of Set | victoria
# Processing Record 253 of Set | teknaf
# Processing Record 254 of Set | qaqortoq
# Processing Record 255 of Set | sitka
# Processing Record 256 of Set | praya
# Processing Record 257 of Set | ondjiva
# Processing Record 258 of Set | san pedro
# Processing Record 259 of Set | stornoway
# Processing Record 260 of Set | brigham city
# Processing Record 261 of Set | heyang
# Processing Record 262 of Set | tiznit
# Processing Record 263 of Set | berlevag
# Processing Record 264 of Set | mizpe ramon
# City not found. Skipping...
# Processing Record 265 of Set | businga
# Processing Record 266 of Set | san patricio
# Processing Record 267 of Set | urengoy
# Processing Record 268 of Set | quatre cocos
# Processing Record 269 of Set | arcachon
# Processing Record 270 of Set | palmas de monte alto
# Processing Record 271 of Set | lata
# Processing Record 272 of Set | sterling
# Processing Record 273 of Set | praia
# Processing Record 274 of Set | chokurdakh
# Processing Record 275 of Set | matamoros
# Processing Record 276 of Set | pastos bons
# Processing Record 277 of Set | luderitz
# Processing Record 278 of Set | faya
# Processing Record 279 of Set | sabang
# Processing Record 280 of Set | zalantun
# Processing Record 281 of Set | kefamenanu
# Processing Record 282 of Set | luau
# Processing Record 283 of Set | ploemeur
# Processing Record 284 of Set | mount gambier
# Processing Record 285 of Set | katsuura
# Processing Record 286 of Set | havre-saint-pierre
# Processing Record 287 of Set | tual
# Processing Record 288 of Set | tumannyy
# City not found. Skipping...
# Processing Record 289 of Set | marcona
# City not found. Skipping...
# Processing Record 290 of Set | clinton
# Processing Record 291 of Set | kuusamo
# Processing Record 292 of Set | flinders
# Processing Record 293 of Set | kahramanmaras
# Processing Record 294 of Set | bogalusa
# Processing Record 295 of Set | whitecourt
# Processing Record 296 of Set | vangaindrano
# Processing Record 297 of Set | ixtapa
# Processing Record 298 of Set | aklavik
# Processing Record 299 of Set | verkhoyansk
# Processing Record 300 of Set | tortosa
# Processing Record 301 of Set | ust-kuyga
# Processing Record 302 of Set | manono
# Processing Record 303 of Set | sunrise manor
# Processing Record 304 of Set | kuito
# Processing Record 305 of Set | turukhansk
# Processing Record 306 of Set | byron bay
# Processing Record 307 of Set | hovd
# Processing Record 308 of Set | pisco
# Processing Record 309 of Set | nantucket
# Processing Record 310 of Set | pasighat
# Processing Record 311 of Set | acari
# Processing Record 312 of Set | miri
# Processing Record 313 of Set | gusau
# Processing Record 314 of Set | westerland
# Processing Record 315 of Set | bambous virieux
# Processing Record 316 of Set | saint-augustin
# Processing Record 317 of Set | kavaratti
# Processing Record 318 of Set | buala
# Processing Record 319 of Set | imbituba
# Processing Record 320 of Set | mitsamiouli
# Processing Record 321 of Set | austin
# Processing Record 322 of Set | novoorsk
# Processing Record 323 of Set | atasu
# Processing Record 324 of Set | arman
# Processing Record 325 of Set | roald
# Processing Record 326 of Set | yakshur-bodya
# City not found. Skipping...
# Processing Record 327 of Set | babanusah
# City not found. Skipping...
# Processing Record 328 of Set | zhigalovo
# Processing Record 329 of Set | upernavik
# Processing Record 330 of Set | taoudenni
# Processing Record 331 of Set | comodoro rivadavia
# Processing Record 332 of Set | oxelosund
# Processing Record 333 of Set | krasnoselkup
# Processing Record 334 of Set | lakes entrance
# Processing Record 335 of Set | tanout
# Processing Record 336 of Set | khandyga
# Processing Record 337 of Set | cidreira
# Processing Record 338 of Set | geraldton
# Processing Record 339 of Set | rosetta
# Processing Record 340 of Set | kaeo
# Processing Record 341 of Set | kieta
# Processing Record 342 of Set | jinan
# Processing Record 343 of Set | komsomolskiy
# Processing Record 344 of Set | karamea
# City not found. Skipping...
# Processing Record 345 of Set | zhuhai
# Processing Record 346 of Set | attawapiskat
# City not found. Skipping...
# Processing Record 347 of Set | hobyo
# Processing Record 348 of Set | saleaula
# City not found. Skipping...
# Processing Record 349 of Set | severo-kurilsk
# Processing Record 350 of Set | vanderhoof
# Processing Record 351 of Set | lorengau
# Processing Record 352 of Set | oskemen
# Processing Record 353 of Set | aksarayskiy
# Processing Record 354 of Set | nizhniy kuranakh
# Processing Record 355 of Set | fare
# Processing Record 356 of Set | te anau
# Processing Record 357 of Set | yulara
# Processing Record 358 of Set | yumen
# Processing Record 359 of Set | pumiao
# Processing Record 360 of Set | san remo
# Processing Record 361 of Set | monrovia
# Processing Record 362 of Set | pinerovka
# Processing Record 363 of Set | mweka
# Processing Record 364 of Set | ushtobe
# Processing Record 365 of Set | canillo
# Processing Record 366 of Set | cullinan
# Processing Record 367 of Set | callaway
# Processing Record 368 of Set | manokwari
# Processing Record 369 of Set | lundazi
# Processing Record 370 of Set | cayenne
# Processing Record 371 of Set | tezu
# Processing Record 372 of Set | wanning
# Processing Record 373 of Set | parabel
# Processing Record 374 of Set | vanimo
# Processing Record 375 of Set | odweyne
# Processing Record 376 of Set | tateyama
# Processing Record 377 of Set | coos bay
# Processing Record 378 of Set | pacific grove
# Processing Record 379 of Set | yabrud
# Processing Record 380 of Set | hendek
# Processing Record 381 of Set | brigantine
# Processing Record 382 of Set | muroto
# Processing Record 383 of Set | camacha
# Processing Record 384 of Set | vestmannaeyjar
# Processing Record 385 of Set | seminole
# Processing Record 386 of Set | constitucion
# Processing Record 387 of Set | provideniya
# Processing Record 388 of Set | jiddah
# City not found. Skipping...
# Processing Record 389 of Set | laguna
# Processing Record 390 of Set | podgornoye
# Processing Record 391 of Set | mashhad
# Processing Record 392 of Set | kempsey
# Processing Record 393 of Set | kiunga
# Processing Record 394 of Set | neiba
# Processing Record 395 of Set | lavrentiya
# Processing Record 396 of Set | chara
# Processing Record 397 of Set | walvis bay
# Processing Record 398 of Set | chuy
# Processing Record 399 of Set | korla
# Processing Record 400 of Set | peniche
# Processing Record 401 of Set | la ronge
# Processing Record 402 of Set | inuvik
# Processing Record 403 of Set | santiago de cao
# Processing Record 404 of Set | ullapool
# Processing Record 405 of Set | puerto cabezas
# Processing Record 406 of Set | plouzane
# Processing Record 407 of Set | seoul
# Processing Record 408 of Set | tunduru
# City not found. Skipping...
# Processing Record 409 of Set | karratha
# Processing Record 410 of Set | nalut
# Processing Record 411 of Set | el balsamo
# Processing Record 412 of Set | triunfo
# Processing Record 413 of Set | okitipupa
# Processing Record 414 of Set | camana
# Processing Record 415 of Set | vostok
# Processing Record 416 of Set | spas-demensk
# Processing Record 417 of Set | yagodnoye
# Processing Record 418 of Set | mgachi
# Processing Record 419 of Set | salalah
# Processing Record 420 of Set | elliot lake
# Processing Record 421 of Set | turgenevo
# Processing Record 422 of Set | kichera
# Processing Record 423 of Set | garowe
# Processing Record 424 of Set | qax
# Processing Record 425 of Set | marfino
# Processing Record 426 of Set | san cristobal
# Processing Record 427 of Set | jalu
# Processing Record 428 of Set | goderich
# Processing Record 429 of Set | sioux lookout
# Processing Record 430 of Set | hoquiam
# Processing Record 431 of Set | moron
# Processing Record 432 of Set | washington
# Processing Record 433 of Set | butembo
# Processing Record 434 of Set | tawkar
# City not found. Skipping...
# Processing Record 435 of Set | jiblah
# Processing Record 436 of Set | pachelma
# Processing Record 437 of Set | necochea
# Processing Record 438 of Set | bardiyah
# Processing Record 439 of Set | waki
# Processing Record 440 of Set | chiredzi
# Processing Record 441 of Set | puri
# Processing Record 442 of Set | sao mateus do maranhao
# Processing Record 443 of Set | port augusta
# Processing Record 444 of Set | barawe
# City not found. Skipping...
# Processing Record 445 of Set | san gabriel
# Processing Record 446 of Set | lazaro cardenas
# Processing Record 447 of Set | bambari
# Processing Record 448 of Set | troitsko-pechorsk
# Processing Record 449 of Set | huarmey
# Processing Record 450 of Set | morondava
# Processing Record 451 of Set | ribeira grande
# Processing Record 452 of Set | the pas
# Processing Record 453 of Set | opunake
# Processing Record 454 of Set | codrington
# Processing Record 455 of Set | aguimes
# Processing Record 456 of Set | tacoronte
# Processing Record 457 of Set | yining
# Processing Record 458 of Set | slobodskoy
# Processing Record 459 of Set | manggar
# Processing Record 460 of Set | pakokku
# Processing Record 461 of Set | nileshwar
# Processing Record 462 of Set | estelle
# Processing Record 463 of Set | fairbanks
# Processing Record 464 of Set | venezuela
# Processing Record 465 of Set | acapulco
# Processing Record 466 of Set | mindelo
# Processing Record 467 of Set | caravelas
# Processing Record 468 of Set | ipixuna
# Processing Record 469 of Set | jimenez
# Processing Record 470 of Set | barra do garcas
# Processing Record 471 of Set | sisimiut
# Processing Record 472 of Set | la paz
# Processing Record 473 of Set | tessalit
# Processing Record 474 of Set | juneau
# Processing Record 475 of Set | dicabisagan
# Processing Record 476 of Set | soddy-daisy
# Processing Record 477 of Set | paita
# Processing Record 478 of Set | tapioszele
# Processing Record 479 of Set | graham
# Processing Record 480 of Set | jijiga
# Processing Record 481 of Set | poladpur
# Processing Record 482 of Set | venice
# Processing Record 483 of Set | calimete
# Processing Record 484 of Set | vila velha
# Processing Record 485 of Set | namatanai
# Processing Record 486 of Set | mustasaari
# Processing Record 487 of Set | ahuimanu
# Processing Record 488 of Set | sorland
# Processing Record 489 of Set | savelugu
# Processing Record 490 of Set | jieshi
# Processing Record 491 of Set | taltal
# Processing Record 492 of Set | bairiki
# Processing Record 493 of Set | fuyu
# Processing Record 494 of Set | santa catarina de tepehuanes
# Processing Record 495 of Set | haines junction
# Processing Record 496 of Set | lensk
# Processing Record 497 of Set | kattivakkam
# Processing Record 498 of Set | hualmay
# Processing Record 499 of Set | egvekinot
# Processing Record 500 of Set | wismar
# Processing Record 501 of Set | utiroa
# City not found. Skipping...
# Processing Record 502 of Set | sibu
# Processing Record 503 of Set | athabasca
# Processing Record 504 of Set | ola
# Processing Record 505 of Set | lasa
# Processing Record 506 of Set | borogontsy
# Processing Record 507 of Set | kolondieba
# Processing Record 508 of Set | olden
# Processing Record 509 of Set | mogadishu
# Processing Record 510 of Set | pitsunda
# Processing Record 511 of Set | cap malheureux
# Processing Record 512 of Set | bewar
# Processing Record 513 of Set | carutapera
# Processing Record 514 of Set | porto velho
# Processing Record 515 of Set | grajau
# Processing Record 516 of Set | abu samrah
# Processing Record 517 of Set | abbeville
# Processing Record 518 of Set | khash
# Processing Record 519 of Set | tabory
# Processing Record 520 of Set | pedernales
# Processing Record 521 of Set | clyde river
# Processing Record 522 of Set | ust-kamchatsk
# City not found. Skipping...
# Processing Record 523 of Set | coquimbo
# Processing Record 524 of Set | sambava
# Processing Record 525 of Set | talesh
# City not found. Skipping...
# Processing Record 526 of Set | tasbuget
# City not found. Skipping...
# Processing Record 527 of Set | mamallapuram
# Processing Record 528 of Set | whitehorse
# Processing Record 529 of Set | one hundred mile house
# City not found. Skipping...
# Processing Record 530 of Set | caconda
# Processing Record 531 of Set | jinchang
# Processing Record 532 of Set | sangar
# Processing Record 533 of Set | linhares
# Processing Record 534 of Set | mouzakion
# City not found. Skipping...
# Processing Record 535 of Set | half moon bay
# Processing Record 536 of Set | ambon
# Processing Record 537 of Set | shimanovsk
# Processing Record 538 of Set | tabriz
# Processing Record 539 of Set | quiroga
# Processing Record 540 of Set | lubao
# Processing Record 541 of Set | labuhan
# Processing Record 542 of Set | pangody
# Processing Record 543 of Set | neuquen
# Processing Record 544 of Set | yangcun
# Processing Record 545 of Set | zhangjiakou
# Processing Record 546 of Set | gazanjyk
# Processing Record 547 of Set | roma
# Processing Record 548 of Set | puerto colombia
# Processing Record 549 of Set | saint-georges
# Processing Record 550 of Set | fortuna
# Processing Record 551 of Set | mahanoro
# Processing Record 552 of Set | awbari
# Processing Record 553 of Set | almeria
# Processing Record 554 of Set | blantyre
# Processing Record 555 of Set | kegayli
# City not found. Skipping...
# Processing Record 556 of Set | serebryansk
# Processing Record 557 of Set | malegaon
# Processing Record 558 of Set | airai
# Processing Record 559 of Set | petropavlovsk-kamchatskiy
# Processing Record 560 of Set | myitkyina
# Processing Record 561 of Set | cheuskiny
# City not found. Skipping...
# Processing Record 562 of Set | tigil
# Processing Record 563 of Set | mapastepec
# Processing Record 564 of Set | peru
# Processing Record 565 of Set | campoverde
# Processing Record 566 of Set | oriximina
# Processing Record 567 of Set | barcelos
# Processing Record 568 of Set | north bend
# Processing Record 569 of Set | zheleznodorozhnyy
# Processing Record 570 of Set | havelock
# Processing Record 571 of Set | horodnya
# Processing Record 572 of Set | jomalig
# City not found. Skipping...
# Processing Record 573 of Set | felanitx
# Processing Record 574 of Set | dubti
# Processing Record 575 of Set | governador valadares
# Processing Record 576 of Set | camabatela
# Processing Record 577 of Set | chaozhou
# Processing Record 578 of Set | srednekolymsk
# Processing Record 579 of Set | calintaan
# Processing Record 580 of Set | nakamura
# Processing Record 581 of Set | labuan
# Processing Record 582 of Set | riyadh
# Processing Record 583 of Set | moshupa
# Processing Record 584 of Set | satipo
# Processing Record 585 of Set | mabaruma
# Processing Record 586 of Set | karancslapujto
# Processing Record 587 of Set | inhambane
# Processing Record 588 of Set | noyabrsk
# Processing Record 589 of Set | bintulu
# Processing Record 590 of Set | waddan
# Processing Record 591 of Set | san policarpo
# Processing Record 592 of Set | macusani
# Processing Record 593 of Set | porbandar
# Processing Record 594 of Set | normandin
# Processing Record 595 of Set | westport
# Processing Record 596 of Set | dickinson
# Processing Record 597 of Set | kars
# Processing Record 598 of Set | mareeba
# Processing Record 599 of Set | gilgil
# City not found. Skipping...
# Processing Record 600 of Set | maceio
# Processing Record 601 of Set | itarema
# Processing Record 602 of Set | kingaroy
# Processing Record 603 of Set | udgir
# Processing Record 604 of Set | kijang
# Processing Record 605 of Set | bumba
# Processing Record 606 of Set | mountain home
# Processing Record 607 of Set | rodrigues alves
# Processing Record 608 of Set | tabiauea
# City not found. Skipping...
# Processing Record 609 of Set | dese
# Processing Record 610 of Set | ausa
# Processing Record 611 of Set | epe
# Processing Record 612 of Set | sataua
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = pd.DataFrame({
    "City": name,
    "Cloudiness": cloud,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed })

cities_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity  Latitude  \
# 0             hue          75      VN  1603601375        94     16.47
# 1         lourdes           0      FR  1603601376        87     43.10
# 2  cabo san lucas           0      MX  1603601246        75     22.89
# 3          anadyr          90      RU  1603601376        92     64.75
# 4    puerto ayora          99      EC  1603601376        95     -0.74
#
#    Longitude  Max Temp  Wind Speed
# 0     107.60     69.80       12.75
# 1      -0.05     44.60        6.93
# 2    -109.91     81.00        1.01
# 3     177.48     24.80        4.47
# 4     -90.35     66.99        1.99

# %%
cities_df.to_csv('/Users/madhuvenkidusamy/Documents/Data Science Bootcamp/Homeworks/python-api-challenge/WeatherPy/cities.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_df.describe()
# Out:
#        Cloudiness          Date   Humidity    Latitude   Longitude  \
# count  564.000000  5.640000e+02  564.00000  564.000000  564.000000
# mean    54.751773  1.603601e+09   74.02305   20.405284   14.899929
# std     38.167837  6.700961e+01   20.44838   32.819691   91.003799
# min      0.000000  1.603601e+09   10.00000  -54.800000 -179.170000
# 25%     19.000000  1.603601e+09   64.00000   -6.975000  -68.082500
# 50%     65.000000  1.603601e+09   78.00000   23.280000   17.090000
# 75%     90.000000  1.603601e+09   90.00000   47.122500   96.385000
# max    100.000000  1.603601e+09  100.00000   78.220000  177.920000
#
#          Max Temp  Wind Speed
# count  564.000000  564.000000
# mean    59.199025    7.608262
# std     20.626768    5.474977
# min      7.970000    0.160000
# 25%     44.600000    3.395000
# 50%     62.600000    6.330000
# 75%     76.222500    9.852500
# max     98.600000   27.630000

# %%
cities_df = cities_df[cities_df['Humidity'] <= 100]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
cities_df.plot(kind = 'scatter', x = 'Latitude', y = "Max Temp", title = "Max Temperature vs. Latitude (10/25/20)")
plt.ylabel("Max Temp (F)")
plt.savefig('lat_temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
cities_df.plot(kind = 'scatter', x = 'Latitude', y = "Humidity", title = "Humidity vs. Latitude (10/25/20)")
plt.ylabel("Humidity (%)")
plt.savefig('lat_humid.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cities_df.plot(kind = 'scatter', x = 'Latitude', y = "Cloudiness", title = "Cloudiness vs. Latitude (10/25/20)")
plt.ylabel("Cloudiness (%)")
plt.savefig('lat_cloud.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
cities_df.plot(kind = 'scatter', x = 'Latitude', y = "Wind Speed", title = "Wind Speed vs. Latitude (10/25/20)")
plt.ylabel("Wind Speed (mph)")
plt.savefig('lat_wind.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
north = cities_df[cities_df['Latitude'] >= 0 ]
south = cities_df[cities_df['Latitude'] <= 0 ]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Max Temperature vs. Latitude for Northern Hemisphere (10/25/20)")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('north_lat_temp.png')
plt.show()
# Out:
# The r-squared is: 0.7927396083488044

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Max Temperature vs. Latitude for Southern Hemisphere (10/25/20)")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('south_lat_temp.png')
plt.show()
# Out:
# The r-squared is: 0.445667589811347

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Humidity vs. Latitude for Northern Hemisphere (10/25/20)")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('north_lat_humid.png')
plt.show()
# Out:
# The r-squared is: 0.08602491764898297

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Humidity vs. Latitude for Southern Hemisphere (10/25/20)")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('south_lat_humid.png')
plt.show()
# Out:
# The r-squared is: 0.009652563838487973

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Cloudiness vs. Latitude for Northern Hemisphere (10/25/20)")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('north_lat_cloud.png')
plt.show()
# Out:
# The r-squared is: 0.01119353004049822

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Cloudiness vs. Latitude for Southern Hemisphere (10/25/20)")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('south_lat_cloud.png')
plt.show()
# Out:
# The r-squared is: 1.640104345591691e-05

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north['Latitude']
y_values = north['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Wind Speed vs. Latitude for Northern Hemisphere (10/25/20)")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('north_lat_wind.png')
plt.show()
# Out:
# The r-squared is: 0.040400762428807774

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south['Latitude']
y_values = south['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Wind Speed vs. Latitude for Southern Hemisphere (10/25/20)")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('south_lat_wind.png')
plt.show()
# Out:
# The r-squared is: 0.015403071878759585

# %% [markdown]
# 3 Observable Trends:
# 1. Temperature and latitude seem to be highly correlated. This is shown by the relatively high r-squared value of the scatter plots that relate temperature and latitude for both the northern and southern hemispheres (0.79 and 0.44), and by looking at the graph, the line of best fit seems to match the plotted scatter points.
# 2. Because this data was randomly generated, we can assume it got a true sample of city distribution in the northern and southern hemispheres. It seems there are more cities in the northern hemisphere than southern hemisphere. This is visually shown, because there appear to be more points on the northern hemisphere graphs than the southern ones. This can also be confirmed by counting the rows in the north dataframe and south dataframe, and there are more in the north dataframe.
# 3. The temperature vs latitude trends are inverse in the north and south. This can be demonstrated in the visuals, as well as correlated by the positive and negative slopes of those regressions. This also makes sense with what we know about the seasons.
